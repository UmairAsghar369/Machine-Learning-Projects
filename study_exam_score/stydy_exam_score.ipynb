# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('study_exam_score_clean.csv')

# %%
data.describe()
# Out:
#        hours_studied  exam_score
# count       10.00000    10.00000
# mean         5.50000    67.00000
# std          3.02765    10.68748
# min          1.00000    52.00000
# 25%          3.25000    59.00000
# 50%          5.50000    66.50000
# 75%          7.75000    74.00000
# max         10.00000    85.00000

# %%
X = DataFrame(data, columns=['hours_studied'])
y = DataFrame(data, columns=['exam_score'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X ,y)
plt.title('Student’s exam score based on the number of hours they studied')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.ylim(51,90)
plt.xlim(0,11)
plt.show()

# %%
regression = LinearRegression()
regression.fit(X ,y)
# Out:
# LinearRegression()

# %%
regression.coef_ # Slpoe
# Out:
# array([[3.51515152]])

# %%
regression.intercept_ # Intercept
# Out:
# array([47.66666667])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X ,y)
plt.plot(X,regression.predict(X),color='orange',linewidth=3)

plt.title('Student’s exam score based on the number of hours they studied')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.ylim(52,90)
plt.xlim(1,11)
plt.show()

# %%
regression.score(X, y)
# Out:
# 0.9916283457139488
